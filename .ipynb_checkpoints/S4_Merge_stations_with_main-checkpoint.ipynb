# %%
import pandas as pd
import numpy as np
#custom script to merge entries
import matplotlib.pyplot as plt
from pathlib import Path  
from utils import filter_by_column_value, plot_range_pie
from geopy.distance import geodesic

# %%
main_dataset = pd.read_csv('preprocessed_data/preprocessed_time_features_added.csv')

# %%
stations_nl = pd.read_csv('preprocessed_data/stations_clean_v1.csv')

# %%
main_dataset.head()
# Out:
#    Journey id Train type Departure station code Arrival station code  \
# 0    15086865  Intercity                    RTD                   DT
# 1    15086865  Intercity                     DT                   GV
# 2    15086865  Intercity                     GV                 LEDN
# 3    15086865  Intercity                   LEDN                  SHL
# 4    15086865  Intercity                    SHL                  ASS
#
#   Departure station name  Arrival station name             Departure time  \
# 0     Rotterdam Centraal                 Delft  2025-01-01T02:02:00+01:00
# 1                  Delft           Den Haag HS  2025-01-01T02:12:00+01:00
# 2            Den Haag HS       Leiden Centraal  2025-01-01T02:22:00+01:00
# 3        Leiden Centraal      Schiphol Airport  2025-01-01T02:33:00+01:00
# 4       Schiphol Airport  Amsterdam Sloterdijk  2025-01-01T02:59:00+01:00
#
#                 Arrival time  Departure delay  Arrival delay  Part number  \
# 0  2025-01-01T02:12:00+01:00              0.0            1.0            1
# 1  2025-01-01T02:19:00+01:00              1.0            1.0            2
# 2  2025-01-01T02:31:00+01:00              0.0            0.0            3
# 3  2025-01-01T02:56:00+01:00              0.0            0.0            4
# 4  2025-01-01T03:07:00+01:00              0.0            0.0            5
#
#    Cancelled  Departure platform changed  Arrival platform changed  \
# 0          0                       False                     False
# 1          0                       False                     False
# 2          0                       False                     False
# 3          0                       False                      True
# 4          0                        True                     False
#
#    Is_weekend  Is_holiday  Is rush hour
# 0       False        True         False
# 1       False        True         False
# 2       False        True         False
# 3       False        True         False
# 4       False        True         False

# %%
mask = main_dataset['Arrival station code'].isin(stations_nl['code'])
unique_count = main_dataset.loc[mask, 'Arrival station code'].nunique()  # fast

# %%
print(unique_count)
# Out:
# 252

# %%
#conclusion: even though there are 397 train stations, we are only working with 257 of them.
#Some one-hot encodings will be excluded then.

# %%
unique_station_types = stations_nl['type'].unique()

# %%
print(unique_station_types)
# Out:
# ['knooppuntIntercitystation' 'stoptreinstation' 'intercitystation'
#  'knooppuntStoptreinstation' 'megastation' 'knooppuntSneltreinstation'
#  'sneltreinstation' 'facultatiefStation']

# %%
main_dataset = (
    main_dataset
        .merge(
            stations_nl[['code', 'type', 'geo_lat', 'geo_lng']],
            left_on='Departure station code',
            right_on='code',
            how='left'
        )
        .rename(columns={
            'type': 'Departure station type',
            'geo_lat': 'Dep geo lat',
            'geo_lng': 'Dep geo lng'
        })
        .drop(columns='code')  # remove duplicate join key
)

# %%
main_dataset = (
    main_dataset
        .merge(
            stations_nl[['code', 'type', 'geo_lat', 'geo_lng']],
            left_on='Arrival station code',
            right_on='code',
            how='left'
        )
        .rename(columns={
            'type': 'Arrival station type',
            'geo_lat': 'Arr geo lat',
            'geo_lng': 'Arr geo lng'
        })
        .drop(columns='code')  # remove duplicate join key
)

# %%
main_dataset.head()
# Out:
#    Journey id Train type Departure station code Arrival station code  \
# 0    15086865  Intercity                    RTD                   DT
# 1    15086865  Intercity                     DT                   GV
# 2    15086865  Intercity                     GV                 LEDN
# 3    15086865  Intercity                   LEDN                  SHL
# 4    15086865  Intercity                    SHL                  ASS
#
#   Departure station name  Arrival station name             Departure time  \
# 0     Rotterdam Centraal                 Delft  2025-01-01T02:02:00+01:00
# 1                  Delft           Den Haag HS  2025-01-01T02:12:00+01:00
# 2            Den Haag HS       Leiden Centraal  2025-01-01T02:22:00+01:00
# 3        Leiden Centraal      Schiphol Airport  2025-01-01T02:33:00+01:00
# 4       Schiphol Airport  Amsterdam Sloterdijk  2025-01-01T02:59:00+01:00
#
#                 Arrival time  Departure delay  Arrival delay  ...  \
# 0  2025-01-01T02:12:00+01:00              0.0            1.0  ...
# 1  2025-01-01T02:19:00+01:00              1.0            1.0  ...
# 2  2025-01-01T02:31:00+01:00              0.0            0.0  ...
# 3  2025-01-01T02:56:00+01:00              0.0            0.0  ...
# 4  2025-01-01T03:07:00+01:00              0.0            0.0  ...
#
#    Arrival platform changed  Is_weekend  Is_holiday  Is rush hour  \
# 0                     False       False        True         False
# 1                     False       False        True         False
# 2                     False       False        True         False
# 3                      True       False        True         False
# 4                     False       False        True         False
#
#       Departure station type  Dep geo lat  Dep geo lng  \
# 0                megastation    51.924999     4.468889
# 1  knooppuntIntercitystation    52.006668     4.356389
# 2  knooppuntIntercitystation    52.069721     4.322500
# 3  knooppuntIntercitystation    52.166111     4.481667
# 4                megastation    52.309444     4.761944
#
#         Arrival station type  Arr geo lat  Arr geo lng
# 0  knooppuntIntercitystation    52.006668     4.356389
# 1  knooppuntIntercitystation    52.069721     4.322500
# 2  knooppuntIntercitystation    52.166111     4.481667
# 3                megastation    52.309444     4.761944
# 4  knooppuntIntercitystation    52.388889     4.837778
#
# [5 rows x 23 columns]

# %%
unique_station_types = stations_nl['type'].unique()

for item in unique_station_types:
    boolean_list = []
    for station in main_dataset["Departure station type"]:
        if station == item:
            boolean_list.append(True)
        else:
            boolean_list.append(False)
    res = all(not i for i in boolean_list)
    if not res:
        main_dataset[f"Dep {item}"] = boolean_list

for item in unique_station_types:
    boolean_list = []
    for station in main_dataset["Arrival station type"]:
        if station == item:
            boolean_list.append(True)
        else:
            boolean_list.append(False)
    res = all(not i for i in boolean_list)
    if not res:
        main_dataset[f"Arr {item}"] = boolean_list

# %%
len(main_dataset)
# Out:
# 3111732

# %%
main_dataset.head()
# Out:
#    Journey id Train type Departure station code Arrival station code  \
# 0    15086865  Intercity                    RTD                   DT
# 1    15086865  Intercity                     DT                   GV
# 2    15086865  Intercity                     GV                 LEDN
# 3    15086865  Intercity                   LEDN                  SHL
# 4    15086865  Intercity                    SHL                  ASS
#
#   Departure station name  Arrival station name             Departure time  \
# 0     Rotterdam Centraal                 Delft  2025-01-01T02:02:00+01:00
# 1                  Delft           Den Haag HS  2025-01-01T02:12:00+01:00
# 2            Den Haag HS       Leiden Centraal  2025-01-01T02:22:00+01:00
# 3        Leiden Centraal      Schiphol Airport  2025-01-01T02:33:00+01:00
# 4       Schiphol Airport  Amsterdam Sloterdijk  2025-01-01T02:59:00+01:00
#
#                 Arrival time  Departure delay  Arrival delay  ...  \
# 0  2025-01-01T02:12:00+01:00              0.0            1.0  ...
# 1  2025-01-01T02:19:00+01:00              1.0            1.0  ...
# 2  2025-01-01T02:31:00+01:00              0.0            0.0  ...
# 3  2025-01-01T02:56:00+01:00              0.0            0.0  ...
# 4  2025-01-01T03:07:00+01:00              0.0            0.0  ...
#
#    Dep intercitystation  Dep knooppuntStoptreinstation  Dep megastation  \
# 0                 False                          False             True
# 1                 False                          False            False
# 2                 False                          False            False
# 3                 False                          False            False
# 4                 False                          False             True
#
#    Dep facultatiefStation  Arr knooppuntIntercitystation  \
# 0                   False                           True
# 1                   False                           True
# 2                   False                           True
# 3                   False                          False
# 4                   False                           True
#
#    Arr stoptreinstation  Arr intercitystation Arr knooppuntStoptreinstation  \
# 0                 False                 False                         False
# 1                 False                 False                         False
# 2                 False                 False                         False
# 3                 False                 False                         False
# 4                 False                 False                         False
#
#    Arr megastation  Arr facultatiefStation
# 0            False                   False
# 1            False                   False
# 2            False                   False
# 3             True                   False
# 4            False                   False
#
# [5 rows x 35 columns]

# %%
filtered = filter_by_column_value(main_dataset, "Dep intercitystation", True)

# %%
filtered.head()
# Out:
#      Journey id Train type Departure station code Arrival station code  \
# 85     15086886   Sprinter                   ASDZ                  SHL
# 107    15086889   Sprinter                    CAS                  UTG
# 219    15086970  Intercity                    ASA                  ASB
# 251    15087019  Intercity                    ASA                  ASB
# 283    15087088  Intercity                    ASA                  ASD
#
#     Departure station name     Arrival station name  \
# 85          Amsterdam Zuid         Schiphol Airport
# 107              Castricum                 Uitgeest
# 219       Amsterdam Amstel  Amsterdam Bijlmer ArenA
# 251       Amsterdam Amstel  Amsterdam Bijlmer ArenA
# 283       Amsterdam Amstel       Amsterdam Centraal
#
#                 Departure time               Arrival time  Departure delay  \
# 85   2025-01-01T05:38:00+01:00  2025-01-01T05:44:00+01:00              1.0
# 107  2025-01-01T05:12:00+01:00  2025-01-01T05:16:00+01:00              2.0
# 219  2025-01-01T08:58:00+01:00  2025-01-01T09:03:00+01:00              0.0
# 251  2025-01-01T09:28:00+01:00  2025-01-01T09:33:00+01:00              0.0
# 283  2025-01-01T09:41:00+01:00  2025-01-01T09:48:00+01:00              0.0
#
#      Arrival delay  ...  Dep intercitystation  Dep knooppuntStoptreinstation  \
# 85             0.0  ...                  True                          False
# 107            4.0  ...                  True                          False
# 219            1.0  ...                  True                          False
# 251            0.0  ...                  True                          False
# 283            2.0  ...                  True                          False
#
#      Dep megastation  Dep facultatiefStation  Arr knooppuntIntercitystation  \
# 85             False                   False                          False
# 107            False                   False                          False
# 219            False                   False                          False
# 251            False                   False                          False
# 283            False                   False                          False
#
#      Arr stoptreinstation  Arr intercitystation Arr knooppuntStoptreinstation  \
# 85                  False                 False                         False
# 107                 False                 False                          True
# 219                 False                 False                          True
# 251                 False                 False                          True
# 283                 False                 False                         False
#
#      Arr megastation  Arr facultatiefStation
# 85              True                   False
# 107            False                   False
# 219            False                   False
# 251            False                   False
# 283             True                   False
#
# [5 rows x 35 columns]

# %%
test_ranges_1 = [(0,0), (1, 2), (3, 5), (6, 10), (11, 20), (21, 40), (41, 180), (180, 1001)]

# %%
plot_range_pie(filtered, "Departure delay", test_ranges_1)
# Out:
# 0–0 - 59.3%, 113186
# 1–2 - 23.3%, 44484
# 3–5 - 6.3%, 11958
# 6–10 - 2.5%, 4785
# 11–20 - 1.1%, 2100
# 21–40 - 0.2%, 391
# 41–180 - 0.0%, 33
# 180–1001 - 7.4%, 14088
# ['0–0 - 59.3%, 113186',
#  '1–2 - 23.3%, 44484',
#  '3–5 - 6.3%, 11958',
#  '6–10 - 2.5%, 4785',
#  '11–20 - 1.1%, 2100',
#  '21–40 - 0.2%, 391',
#  '41–180 - 0.0%, 33',
#  '180–1001 - 7.4%, 14088']

# %%
main_dataset = main_dataset.drop(['Arrival station type', 'Departure station type'], axis = 1)

# %%
main_dataset.head()
# Out:
#    Journey id Train type Departure station code Arrival station code  \
# 0    15086865  Intercity                    RTD                   DT
# 1    15086865  Intercity                     DT                   GV
# 2    15086865  Intercity                     GV                 LEDN
# 3    15086865  Intercity                   LEDN                  SHL
# 4    15086865  Intercity                    SHL                  ASS
#
#   Departure station name  Arrival station name             Departure time  \
# 0     Rotterdam Centraal                 Delft  2025-01-01T02:02:00+01:00
# 1                  Delft           Den Haag HS  2025-01-01T02:12:00+01:00
# 2            Den Haag HS       Leiden Centraal  2025-01-01T02:22:00+01:00
# 3        Leiden Centraal      Schiphol Airport  2025-01-01T02:33:00+01:00
# 4       Schiphol Airport  Amsterdam Sloterdijk  2025-01-01T02:59:00+01:00
#
#                 Arrival time  Departure delay  Arrival delay  ...  \
# 0  2025-01-01T02:12:00+01:00              0.0            1.0  ...
# 1  2025-01-01T02:19:00+01:00              1.0            1.0  ...
# 2  2025-01-01T02:31:00+01:00              0.0            0.0  ...
# 3  2025-01-01T02:56:00+01:00              0.0            0.0  ...
# 4  2025-01-01T03:07:00+01:00              0.0            0.0  ...
#
#    Dep intercitystation  Dep knooppuntStoptreinstation  Dep megastation  \
# 0                 False                          False             True
# 1                 False                          False            False
# 2                 False                          False            False
# 3                 False                          False            False
# 4                 False                          False             True
#
#    Dep facultatiefStation  Arr knooppuntIntercitystation  \
# 0                   False                           True
# 1                   False                           True
# 2                   False                           True
# 3                   False                          False
# 4                   False                           True
#
#    Arr stoptreinstation  Arr intercitystation  Arr knooppuntStoptreinstation  \
# 0                 False                 False                          False
# 1                 False                 False                          False
# 2                 False                 False                          False
# 3                 False                 False                          False
# 4                 False                 False                          False
#
#    Arr megastation  Arr facultatiefStation
# 0            False                   False
# 1            False                   False
# 2            False                   False
# 3             True                   False
# 4            False                   False
#
# [5 rows x 33 columns]

# %%
distance_arrival_departure = []

for _, row in main_dataset.iterrows():
    dep_latitude = row["Dep geo lat"]
    dep_longtitude = row["Dep geo lng"]
    arr_latitude = row["Arr geo lat"]
    arr_longtitude = row["Arr geo lng"]
    distance = geodesic((dep_latitude, dep_longtitude), (arr_latitude, arr_longtitude))
    distance_arrival_departure.append(distance)

main_dataset["Distance"] = distance_arrival_departure
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_49060/398998888.py in <module>
#       6     arr_latitude = row["Arr geo lat"]
#       7     arr_longtitude = row["Arr geo lng"]
# ----> 8     distance = geodesic((dep_latitude, dep_longtitude), (arr_latitude, arr_longtitude))
#       9     distance_arrival_departure.append(distance)
#      10
#
# ~/.local/lib/python3.10/site-packages/geopy/distance.py in __init__(self, *args, **kwargs)
#     538         self.set_ellipsoid(kwargs.pop('ellipsoid', 'WGS-84'))
#     539         major, minor, f = self.ELLIPSOID
# --> 540         super().__init__(*args, **kwargs)
#     541
#     542     def set_ellipsoid(self, ellipsoid):
#
# ~/.local/lib/python3.10/site-packages/geopy/distance.py in __init__(self, *args, **kwargs)
#     274         elif len(args) > 1:
#     275             for a, b in util.pairwise(args):
# --> 276                 kilometers += self.measure(a, b)
#     277
#     278         kilometers += units.kilometers(**kwargs)
#
# ~/.local/lib/python3.10/site-packages/geopy/distance.py in measure(self, a, b)
#     554
#     555     def measure(self, a, b):
# --> 556         a, b = Point(a), Point(b)
#     557         _ensure_same_altitude(a, b)
#     558         lat1, lon1 = a.latitude, a.longitude
#
# ~/.local/lib/python3.10/site-packages/geopy/point.py in __new__(cls, latitude, longitude, altitude)
#     173                     )
#     174                 else:
# --> 175                     return cls.from_sequence(seq)
#     176
#     177         if single_arg:
#
# ~/.local/lib/python3.10/site-packages/geopy/point.py in from_sequence(cls, seq)
#     470             raise ValueError('When creating a Point from sequence, it '
#     471                              'must not have more than 3 items.')
# --> 472         return cls(*args)
#     473
#     474     @classmethod
#
# ~/.local/lib/python3.10/site-packages/geopy/point.py in __new__(cls, latitude, longitude, altitude)
#     186
#     187         latitude, longitude, altitude = \
# --> 188             _normalize_coordinates(latitude, longitude, altitude)
#     189
#     190         self = super().__new__(cls)
#
# ~/.local/lib/python3.10/site-packages/geopy/point.py in _normalize_coordinates(latitude, longitude, altitude)
#      61     is_all_finite = all(isfinite(x) for x in (latitude, longitude, altitude))
#      62     if not is_all_finite:
# ---> 63         raise ValueError('Point coordinates must be finite. %r has been passed '
#      64                          'as coordinates.' % ((latitude, longitude, altitude),))
#      65
#
# ValueError: Point coordinates must be finite. (nan, nan, 0.0) has been passed as coordinates.

# %%
main_dataset.head()
