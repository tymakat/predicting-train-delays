# %%
import pandas as pd
import merging
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import multiprocessing
from multiprocessing import Pool, cpu_count
import queue # imported for using queue.Empty exception
from datetime import date
from pathlib import Path  
from multiprocessing import Process, Lock

# %% [markdown]
# #### Advanced data preprocessing.
#
# ##### Reshaping the dataset's structure.
#
# After performing some basic level data preprocessing, by adding 3 new features, and doing data cleaning, where I have mainly dealt with rare and NaN values, it's time to change the way of thinking behind preprocessing the dataset. So far all of my efforts were aimed to make my dataset clean and feature-relevant (using only features that I will need).
#
# However another important thing to consider is the shape of the user's input. How would the model give the delay prediction for, say, a journey from Eindhoven Centraal to Breda, with a stop at Tilburg? In the current state of the dataset my algorithm would make a prediction based on every trip from the given station, even to and from unrelated cities such as Maastricht or Zwolle.
#
# Since my data is already separated by journeys and stop id's, my plan is to go further and make each entry represent a a part of the journey and not a particular stop.
# For example a new dataset entry would have the following features: Departure City, Arrival City, Departure Time, arrival time, total delay, and so on.
# So simply saying, I would merge every neighboring entry together, so that a model would be able to make a prediction based on specific journeys from one city to another.
#
# Let's take a look at the dataset once more

# %%
basic_info = pd.read_csv('preprocessed_data/main_preprocessed_dataset.csv')
basic_info.head(6)
# Out:
#    Journey id        Date Train type Railroad company  Train number  \
# 0     7914217  2022-01-01  Intercity               NS          1410
# 1     7914217  2022-01-01  Intercity               NS          1410
# 2     7914217  2022-01-01  Intercity               NS          1410
# 3     7914217  2022-01-01  Intercity               NS          1410
# 4     7914217  2022-01-01  Intercity               NS          1410
# 5     7914217  2022-01-01  Intercity               NS          1410
#
#   Station code        Station name               Arrival time  Arrival delay  \
# 0          RTD  Rotterdam Centraal  2022-01-01 02:00:00+01:00            0.0
# 1           DT               Delft  2022-01-01T02:13:00+01:00            3.0
# 2           GV         Den Haag HS  2022-01-01T02:21:00+01:00            2.0
# 3         LEDN     Leiden Centraal  2022-01-01T02:36:00+01:00            0.0
# 4          SHL    Schiphol Airport  2022-01-01T03:01:00+01:00            0.0
# 5          ASD  Amsterdam Centraal  2022-01-01T03:17:00+01:00            0.0
#
#               Departure time  Departure delay  Departure cancelled  Stop id  \
# 0  2022-01-01T02:00:00+01:00              4.0                False        1
# 1  2022-01-01T02:13:00+01:00              4.0                False        2
# 2  2022-01-01T02:23:00+01:00              1.0                False        3
# 3  2022-01-01T02:45:00+01:00              0.0                False        4
# 4  2022-01-01T03:03:00+01:00              0.0                False        5
# 5  2022-01-01T03:23:00+01:00              0.0                False        6
#
#    Is_weekend  Is_holiday
# 0        True        True
# 1        True        True
# 2        True        True
# 3        True        True
# 4        True        True
# 5        True        True

# %% [markdown]
# First things first, let's get rid of column "Date" and merge arrival delay and departure delay columns together.

# %%
basic_info.drop("Date", inplace = True, axis = 1)

# %%
#basic_info['Total delay'] = basic_info['Arrival delay'], basic_info['Departure delay']])

# %%
basic_info.head()
basic_info = basic_info.head(1000000)
len(basic_info)
# Out:
# 1000000

# %%
num_processes = cpu_count()
grouped_data = basic_info.groupby('Journey id')
args_list = [(journey_id, group) for journey_id, group in grouped_data]

# %%
results = []
with Pool(num_processes - 1) as pool:
    # Use the apply method to process each group in parallel
    results = pool.map(merging.merge_func, args_list)
pool.close()
pool.join()

results = pd.concat(results)

# %%
disruptions = pd.read_csv('preprocessed_data/disruptions_preprocessed.csv')
disruptions.head()
# Out:
#                                            rdt_lines  \
# 0                   Den Haag HS - Rotterdam Centraal
# 1  's-Hertogenbosch - Utrecht Centraal, Amsterdam...
# 2                                  Eindhoven - Venlo
# 3                                  Heerlen - Sittard
# 4  Amersfoort - Amsterdam Centraal, Amersfoort - ...
#
#                                    rdt_station_names  \
# 0  Delft,Delft Campus,Den Haag HS,Den Haag Moerwi...
# 1  Abcoude,Amsterdam Amstel,Amsterdam Bijlmer Are...
# 2                 Blerick,Deurne,Horst-Sevenum,Venlo
# 3  Geleen Oost,Hoensbroek,Heerlen,Nuth,Spaubeek,S...
# 4                               Naarden-Bussum,Weesp
#
#                                    rdt_station_codes       cause_group  \
# 0                            DT, DTCP, GV, GVMW, RSW          external
# 1  AC, ASA, ASB, ASD, ASDM, ASHD, BKL, CL, DVD, G...  engineering work
# 2                                    BR, DN, HRT, VL         accidents
# 3                     GLN, HB, HRL, NH, SBK, SN, STD  engineering work
# 4                                            NDB, WP  engineering work
#
#             start_time             end_time  duration_minutes
# 0  2022-01-01 05:45:33  2022-01-01 06:34:58              49.0
# 1  2022-01-01 06:23:54  2022-01-01 13:59:14             455.0
# 2  2022-01-01 07:31:39  2022-01-01 11:26:38             235.0
# 3  2022-01-01 16:06:23  2022-01-01 16:46:33              40.0
# 4  2022-01-01 16:17:56  2022-01-01 17:18:47              61.0

# %% [markdown]
# #### Next step: Merging journeys with disruptions.
# Now that the whole dataset is conveniently split into journeys and journey parts, it is possible to use an open source disruptions dataset to find out whether a disruption took place on one or more journey parts. This would not be possible with the old dataset, since most of the disruptions (such as engineering works, or rolling stock problems) take place on tracks in between stations, so knowing both departure and arrival station is required, in order to achieve maximum accuracy.
#
# Let's write code for reading every station in rdt_station_codes feature and compare this information against the info in main dataset.
# ##### The logic is simple:
# 1) Create new feature called Disruptions.
# 2) Check if the disruption has ended after the train have departed
# 3) Check if rdt_station_codes contain both the arrival station and departure station
# 4) If all requirements are satisfied then Disruption value is True
# 5) Otherwire it is false
#
# Now I do understand that this is also not entirely correct, since there are specific disruptions that are limited to only 1 station. However, the code that I would write below could be easily changed in the future, so I'll stick with this system for now
#
# ##### Additional preprocessing - Unified date time format in main dataset and disruptions dataset
# As you can see currently the datasets store dates in a different format. In order to compare the 'Departure time' feature against 'end_time' feature I have to make sure they are stored in one unified format

# %%
results.head()
# Out:
#    Journey id Train type Railroad company  Train number  \
# 0     7914217  Intercity               NS          1410
# 1     7914217  Intercity               NS          1410
# 2     7914217  Intercity               NS          1410
# 3     7914217  Intercity               NS          1410
# 4     7914217  Intercity               NS          1410
#
#   Departure station code Arrival station code Departure station name  \
# 0                    RTD                   DT     Rotterdam Centraal
# 1                     DT                   GV                  Delft
# 2                     GV                 LEDN            Den Haag HS
# 3                   LEDN                  SHL        Leiden Centraal
# 4                    SHL                  ASD       Schiphol Airport
#
#   Arrival station name  Total journey delay             Departure time  \
# 0                Delft                  4.0  2022-01-01T02:00:00+01:00
# 1          Den Haag HS                  7.0  2022-01-01T02:13:00+01:00
# 2      Leiden Centraal                  3.0  2022-01-01T02:23:00+01:00
# 3     Schiphol Airport                  0.0  2022-01-01T02:45:00+01:00
# 4   Amsterdam Centraal                  0.0  2022-01-01T03:03:00+01:00
#
#                 Arrival time  Is weekend  Is holiday  Part number  Cancelled
# 0  2022-01-01T02:13:00+01:00        True        True            1      False
# 1  2022-01-01T02:21:00+01:00        True        True            2      False
# 2  2022-01-01T02:36:00+01:00        True        True            3      False
# 3  2022-01-01T03:01:00+01:00        True        True            4      False
# 4  2022-01-01T03:17:00+01:00        True        True            5      False

# %%
from dateutil.parser import parse

disruptions["start_time"] = disruptions["start_time"].apply(lambda x: pd.to_datetime(x).strftime('%Y-%m-%d %H:%M:%S'))
disruptions["end_time"] = disruptions["end_time"].apply(lambda x: pd.to_datetime(x).strftime('%Y-%m-%d %H:%M:%S'))

# %%
def check_for_disruptions(departure, arrival, departure_time, arrival_time):
    # Create boolean masks for each condition
    mask_departure = disruptions['rdt_station_codes'].apply(lambda x: departure in x)
    mask_arrival = disruptions['rdt_station_codes'].apply(lambda x: arrival in x)
    mask_time = (disruptions['end_time'] > departure_time) & (disruptions['start_time'] < arrival_time)
    
    # Combine the masks using logical AND
    result = mask_departure & mask_arrival & mask_time
    
    return result.any()

# %%
df_split = np.array_split(results, num_processes - 1)
# Out:
# C:\Users\tymak\AppData\Roaming\Python\Python311\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
with Pool(num_processes - 1) as pool:
    # Use the apply method to process each group in parallel
    merged = pool.map(merging.unify_date_time_format, df_split)

# %%
df = pd.concat(merged)
df['Disruptions'] = df.apply(lambda row: check_for_disruptions(row['Departure station code'], row['Arrival station code'], row['Departure time'], row['Arrival time']), axis=1)

# %%
cancelled = df[df['Cancelled'] == True]
cancelled.head(20)
# Out:
#    Journey id Train type Railroad company  Train number  \
# 2     7914227  Intercity               NS          1422
# 0     7914234   Sprinter               NS          5110
# 1     7914234   Sprinter               NS          5110
# 2     7914234   Sprinter               NS          5110
# 3     7914234   Sprinter               NS          5110
# 4     7914234   Sprinter               NS          5110
# 5     7914234   Sprinter               NS          5110
# 2     7914243  Intercity               NS          1426
# 0     7914256   Sprinter               NS          5123
# 1     7914256   Sprinter               NS          5123
# 2     7914256   Sprinter               NS          5123
# 3     7914256   Sprinter               NS          5123
# 4     7914256   Sprinter               NS          5123
# 5     7914256   Sprinter               NS          5123
# 6     7914256   Sprinter               NS          5123
# 2     7914257  Intercity               NS          2223
# 3     7914257  Intercity               NS          2223
# 4     7914257  Intercity               NS          2223
# 5     7914257  Intercity               NS          2223
# 6     7914257  Intercity               NS          2223
#
#   Departure station code Arrival station code Departure station name  \
# 2                     DT                   GV                  Delft
# 0                    RTD                  SDM     Rotterdam Centraal
# 1                    SDM                 DTCP       Schiedam Centrum
# 2                   DTCP                   DT           Delft Campus
# 3                     DT                  RSW                  Delft
# 4                    RSW                 GVMW               Rijswijk
# 5                   GVMW                   GV      Den Haag Moerwijk
# 2                     DT                   GV                  Delft
# 0                    GVC                   GV      Den Haag Centraal
# 1                     GV                 GVMW            Den Haag HS
# 2                   GVMW                  RSW      Den Haag Moerwijk
# 3                    RSW                   DT               Rijswijk
# 4                     DT                 DTCP                  Delft
# 5                   DTCP                  SDM           Delft Campus
# 6                    SDM                  RTD       Schiedam Centrum
# 2                    RTD                  SDM     Rotterdam Centraal
# 3                    SDM                   DT       Schiedam Centrum
# 4                     DT                   GV                  Delft
# 5                     GV                  LAA            Den Haag HS
# 6                    LAA                 LEDN    Den Haag Laan v NOI
#
#   Arrival station name  Total journey delay       Departure time  \
# 2          Den Haag HS                  0.0  2022-01-01 05:12:00
# 0     Schiedam Centrum                  0.0  2022-01-01 05:36:00
# 1         Delft Campus                  0.0  2022-01-01 05:41:00
# 2                Delft                  0.0  2022-01-01 05:47:00
# 3             Rijswijk                  0.0  2022-01-01 05:50:00
# 4    Den Haag Moerwijk                  0.0  2022-01-01 05:54:00
# 5          Den Haag HS                  0.0  2022-01-01 05:57:00
# 2          Den Haag HS                  0.0  2022-01-01 06:13:00
# 0          Den Haag HS                  0.0  2022-01-01 06:24:00
# 1    Den Haag Moerwijk                  0.0  2022-01-01 06:29:00
# 2             Rijswijk                  0.0  2022-01-01 06:32:00
# 3                Delft                  0.0  2022-01-01 06:35:00
# 4         Delft Campus                  0.0  2022-01-01 06:39:00
# 5     Schiedam Centrum                  0.0  2022-01-01 06:42:00
# 6   Rotterdam Centraal                  0.0  2022-01-01 06:49:00
# 2     Schiedam Centrum                  1.0  2022-01-01 06:42:00
# 3                Delft                  0.0  2022-01-01 06:46:00
# 4          Den Haag HS                  0.0  2022-01-01 06:54:00
# 5  Den Haag Laan v NOI                  0.0  2022-01-01 07:03:00
# 6      Leiden Centraal                  0.0  2022-01-01 07:06:00
#
#                 Arrival time  Is weekend  Is holiday  Part number  Cancelled  \
# 2  2022-01-01T05:21:00+01:00        True        True            3       True
# 0  2022-01-01T05:41:00+01:00        True        True            1       True
# 1  2022-01-01T05:47:00+01:00        True        True            2       True
# 2  2022-01-01T05:50:00+01:00        True        True            3       True
# 3  2022-01-01T05:54:00+01:00        True        True            4       True
# 4  2022-01-01T05:57:00+01:00        True        True            5       True
# 5  2022-01-01T06:01:00+01:00        True        True            6       True
# 2  2022-01-01T06:21:00+01:00        True        True            3       True
# 0  2022-01-01T06:27:00+01:00        True        True            1       True
# 1  2022-01-01T06:32:00+01:00        True        True            2       True
# 2  2022-01-01T06:35:00+01:00        True        True            3       True
# 3  2022-01-01T06:39:00+01:00        True        True            4       True
# 4  2022-01-01T06:42:00+01:00        True        True            5       True
# 5  2022-01-01T06:49:00+01:00        True        True            6       True
# 6  2022-01-01T06:54:00+01:00        True        True            7       True
# 2  2022-01-01T06:46:00+01:00        True        True            3       True
# 3  2022-01-01T06:54:00+01:00        True        True            4       True
# 4  2022-01-01T07:01:00+01:00        True        True            5       True
# 5  2022-01-01T07:06:00+01:00        True        True            6       True
# 6  2022-01-01T07:15:00+01:00        True        True            7       True
#
#    Disruptions
# 2         True
# 0        False
# 1        False
# 2         True
# 3         True
# 4         True
# 5         True
# 2         True
# 0        False
# 1         True
# 2         True
# 3        False
# 4        False
# 5        False
# 6        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False

# %%
delays = df[df['Total journey delay'] > 0]

# %% [markdown]
# print(len(disruptions_true))
# percentage = (len(disruptions_true) / len(df)) * 100
# print("There's " + str(percentage) + " % of journeys with no disruptions")

# %%
print(len(cancelled))
percentage = (len(cancelled) / len(df)) * 100
print("There's " + str(percentage) + " % of journeys with cancellations")
# Out:
# 33218
# There's 3.748000081237885 % of journeys with cancellations

# %%
print(len(delays))
percentage = (len(delays) / len(df)) * 100
print("There's " + str(percentage) + " % of journeys with delays")
# Out:
# 226792
# There's 25.58903108026077 % of journeys with delays

# %%
df.head(50)
# Out:
#     Journey id Train type Railroad company  Train number  \
# 0      7914217  Intercity               NS          1410
# 1      7914217  Intercity               NS          1410
# 2      7914217  Intercity               NS          1410
# 3      7914217  Intercity               NS          1410
# 4      7914217  Intercity               NS          1410
# 0      7914219  Intercity               NS          1409
# 1      7914219  Intercity               NS          1409
# 2      7914219  Intercity               NS          1409
# 3      7914219  Intercity               NS          1409
# 4      7914219  Intercity               NS          1409
# 0      7914220  Intercity               NS          1414
# 1      7914220  Intercity               NS          1414
# 2      7914220  Intercity               NS          1414
# 3      7914220  Intercity               NS          1414
# 4      7914220  Intercity               NS          1414
# 0      7914221  Intercity               NS          1413
# 1      7914221  Intercity               NS          1413
# 2      7914221  Intercity               NS          1413
# 3      7914221  Intercity               NS          1413
# 4      7914221  Intercity               NS          1413
# 0      7914223  Intercity               NS          1418
# 1      7914223  Intercity               NS          1418
# 2      7914223  Intercity               NS          1418
# 3      7914223  Intercity               NS          1418
# 4      7914223  Intercity               NS          1418
# 0      7914224  Intercity               NS          1417
# 1      7914224  Intercity               NS          1417
# 2      7914224  Intercity               NS          1417
# 3      7914224  Intercity               NS          1417
# 4      7914224  Intercity               NS          1417
# 5      7914224  Intercity               NS          1417
# 0      7914225   Sprinter               NS          4308
# 1      7914225   Sprinter               NS          4308
# 2      7914225   Sprinter               NS          4308
# 3      7914225   Sprinter               NS          4308
# 4      7914225   Sprinter               NS          4308
# 5      7914225   Sprinter               NS          4308
# 6      7914225   Sprinter               NS          4308
# 7      7914225   Sprinter               NS          4308
# 8      7914225   Sprinter               NS          4308
# 9      7914225   Sprinter               NS          4308
# 10     7914225   Sprinter               NS          4308
# 11     7914225   Sprinter               NS          4308
# 0      7914226   Sprinter               NS         15808
# 1      7914226   Sprinter               NS         15808
# 2      7914226   Sprinter               NS         15808
# 3      7914226   Sprinter               NS         15808
# 4      7914226   Sprinter               NS         15808
# 5      7914226   Sprinter               NS         15808
# 6      7914226   Sprinter               NS         15808
#
#    Departure station code Arrival station code Departure station name  \
# 0                     RTD                   DT     Rotterdam Centraal
# 1                      DT                   GV                  Delft
# 2                      GV                 LEDN            Den Haag HS
# 3                    LEDN                  SHL        Leiden Centraal
# 4                     SHL                  ASD       Schiphol Airport
# 0                      UT                  ASD       Utrecht Centraal
# 1                     ASD                  SHL     Amsterdam Centraal
# 2                     SHL                 LEDN       Schiphol Airport
# 3                    LEDN                   GV        Leiden Centraal
# 4                      GV                   DT            Den Haag HS
# 0                     RTD                   DT     Rotterdam Centraal
# 1                      DT                   GV                  Delft
# 2                      GV                 LEDN            Den Haag HS
# 3                    LEDN                  SHL        Leiden Centraal
# 4                     SHL                  ASD       Schiphol Airport
# 0                      UT                  ASD       Utrecht Centraal
# 1                     ASD                  SHL     Amsterdam Centraal
# 2                     SHL                 LEDN       Schiphol Airport
# 3                    LEDN                   GV        Leiden Centraal
# 4                      GV                   DT            Den Haag HS
# 0                     RTD                   DT     Rotterdam Centraal
# 1                      DT                   GV                  Delft
# 2                      GV                 LEDN            Den Haag HS
# 3                    LEDN                  SHL        Leiden Centraal
# 4                     SHL                  ASD       Schiphol Airport
# 0                      UT                  ASD       Utrecht Centraal
# 1                     ASD                  SHL     Amsterdam Centraal
# 2                     SHL                 LEDN       Schiphol Airport
# 3                    LEDN                   GV        Leiden Centraal
# 4                      GV                   GD            Den Haag HS
# 5                      GD                   DT                  Gouda
# 0                     LLS                 ALMO       Lelystad Centrum
# 1                    ALMO                 ALMB    Almere Oostvaarders
# 2                    ALMB                 ALMP          Almere Buiten
# 3                    ALMP                  ALM        Almere Parkwijk
# 4                     ALM                 ALMM         Almere Centrum
# 5                    ALMM                 AMPO      Almere Muziekwijk
# 6                    AMPO                   WP           Almere Poort
# 7                      WP                 DMNZ                  Weesp
# 8                    DMNZ                  DVD            Diemen Zuid
# 9                     DVD                  RAI           Duivendrecht
# 10                    RAI                 ASDZ          Amsterdam RAI
# 11                   ASDZ                  SHL         Amsterdam Zuid
# 0                     AMF                  BRN    Amersfoort Centraal
# 1                     BRN                  HVS                  Baarn
# 2                     HVS                 HVSM              Hilversum
# 3                    HVSM                 BSMZ   Hilversum Media Park
# 4                    BSMZ                  NDB            Bussum Zuid
# 5                     NDB                   WP         Naarden-Bussum
# 6                      WP                  DMN                  Weesp
#
#     Arrival station name  Total journey delay       Departure time  \
# 0                  Delft                  4.0  2022-01-01 02:00:00
# 1            Den Haag HS                  7.0  2022-01-01 02:13:00
# 2        Leiden Centraal                  3.0  2022-01-01 02:23:00
# 3       Schiphol Airport                  0.0  2022-01-01 02:45:00
# 4     Amsterdam Centraal                  0.0  2022-01-01 03:03:00
# 0     Amsterdam Centraal                  4.0  2022-01-01 02:16:00
# 1       Schiphol Airport                  2.0  2022-01-01 02:46:00
# 2        Leiden Centraal                  0.0  2022-01-01 03:05:00
# 3            Den Haag HS                  0.0  2022-01-01 03:23:00
# 4                  Delft                  0.0  2022-01-01 03:38:00
# 0                  Delft                  0.0  2022-01-01 03:00:00
# 1            Den Haag HS                  0.0  2022-01-01 03:12:00
# 2        Leiden Centraal                  0.0  2022-01-01 03:23:00
# 3       Schiphol Airport                  0.0  2022-01-01 03:45:00
# 4     Amsterdam Centraal                  0.0  2022-01-01 04:03:00
# 0     Amsterdam Centraal                  0.0  2022-01-01 03:10:00
# 1       Schiphol Airport                  2.0  2022-01-01 03:46:00
# 2        Leiden Centraal                  0.0  2022-01-01 04:05:00
# 3            Den Haag HS                  0.0  2022-01-01 04:23:00
# 4                  Delft                  0.0  2022-01-01 04:38:00
# 0                  Delft                  1.0  2022-01-01 04:00:00
# 1            Den Haag HS                  2.0  2022-01-01 04:13:00
# 2        Leiden Centraal                  4.0  2022-01-01 04:23:00
# 3       Schiphol Airport                  0.0  2022-01-01 04:45:00
# 4     Amsterdam Centraal                 11.0  2022-01-01 05:02:00
# 0     Amsterdam Centraal                  2.0  2022-01-01 04:10:00
# 1       Schiphol Airport                  9.0  2022-01-01 04:46:00
# 2        Leiden Centraal                  3.0  2022-01-01 05:05:00
# 3            Den Haag HS                  0.0  2022-01-01 05:23:00
# 4                  Gouda                  5.0  2022-01-01 05:38:00
# 5                  Delft                  1.0  2022-01-01 06:08:00
# 0    Almere Oostvaarders                  0.0  2022-01-01 04:44:00
# 1          Almere Buiten                  0.0  2022-01-01 04:55:00
# 2        Almere Parkwijk                  0.0  2022-01-01 04:58:00
# 3         Almere Centrum                  0.0  2022-01-01 05:02:00
# 4      Almere Muziekwijk                  0.0  2022-01-01 05:05:00
# 5           Almere Poort                  0.0  2022-01-01 05:08:00
# 6                  Weesp                  0.0  2022-01-01 05:12:00
# 7            Diemen Zuid                  0.0  2022-01-01 05:23:00
# 8           Duivendrecht                  0.0  2022-01-01 05:29:00
# 9          Amsterdam RAI                  0.0  2022-01-01 05:32:00
# 10        Amsterdam Zuid                  0.0  2022-01-01 05:36:00
# 11      Schiphol Airport                  0.0  2022-01-01 05:41:00
# 0                  Baarn                  0.0  2022-01-01 04:48:00
# 1              Hilversum                  0.0  2022-01-01 04:55:00
# 2   Hilversum Media Park                  0.0  2022-01-01 05:02:00
# 3            Bussum Zuid                  0.0  2022-01-01 05:04:00
# 4         Naarden-Bussum                  0.0  2022-01-01 05:08:00
# 5                  Weesp                  1.0  2022-01-01 05:11:00
# 6                 Diemen                  0.0  2022-01-01 05:21:00
#
#                  Arrival time  Is weekend  Is holiday  Part number  Cancelled  \
# 0   2022-01-01T02:13:00+01:00        True        True            1      False
# 1   2022-01-01T02:21:00+01:00        True        True            2      False
# 2   2022-01-01T02:36:00+01:00        True        True            3      False
# 3   2022-01-01T03:01:00+01:00        True        True            4      False
# 4   2022-01-01T03:17:00+01:00        True        True            5      False
# 0   2022-01-01T02:44:00+01:00        True        True            1      False
# 1   2022-01-01T03:01:00+01:00        True        True            2      False
# 2   2022-01-01T03:21:00+01:00        True        True            3      False
# 3   2022-01-01T03:37:00+01:00        True        True            4      False
# 4   2022-01-01T03:45:00+01:00        True        True            5      False
# 0   2022-01-01T03:12:00+01:00        True        True            1      False
# 1   2022-01-01T03:21:00+01:00        True        True            2      False
# 2   2022-01-01T03:36:00+01:00        True        True            3      False
# 3   2022-01-01T04:01:00+01:00        True        True            4      False
# 4   2022-01-01T04:17:00+01:00        True        True            5      False
# 0   2022-01-01T03:44:00+01:00        True        True            1      False
# 1   2022-01-01T04:01:00+01:00        True        True            2      False
# 2   2022-01-01T04:21:00+01:00        True        True            3      False
# 3   2022-01-01T04:37:00+01:00        True        True            4      False
# 4   2022-01-01T04:45:00+01:00        True        True            5      False
# 0   2022-01-01T04:13:00+01:00        True        True            1      False
# 1   2022-01-01T04:21:00+01:00        True        True            2      False
# 2   2022-01-01T04:36:00+01:00        True        True            3      False
# 3   2022-01-01T05:01:00+01:00        True        True            4      False
# 4   2022-01-01T05:16:00+01:00        True        True            5      False
# 0   2022-01-01T04:44:00+01:00        True        True            1      False
# 1   2022-01-01T05:01:00+01:00        True        True            2      False
# 2   2022-01-01T05:21:00+01:00        True        True            3      False
# 3   2022-01-01T05:37:00+01:00        True        True            4      False
# 4   2022-01-01T06:00:00+01:00        True        True            5      False
# 5   2022-01-01T05:45:00+01:00        True        True            6      False
# 0   2022-01-01T04:55:00+01:00        True        True            1      False
# 1   2022-01-01T04:58:00+01:00        True        True            2      False
# 2   2022-01-01T05:02:00+01:00        True        True            3      False
# 3   2022-01-01T05:05:00+01:00        True        True            4      False
# 4   2022-01-01T05:08:00+01:00        True        True            5      False
# 5   2022-01-01T05:12:00+01:00        True        True            6      False
# 6   2022-01-01T05:19:00+01:00        True        True            7      False
# 7   2022-01-01T05:29:00+01:00        True        True            8      False
# 8   2022-01-01T05:32:00+01:00        True        True            9      False
# 9   2022-01-01T05:36:00+01:00        True        True           10      False
# 10  2022-01-01T05:38:00+01:00        True        True           11      False
# 11  2022-01-01T05:47:00+01:00        True        True           12      False
# 0   2022-01-01T04:55:00+01:00        True        True            1      False
# 1   2022-01-01T05:01:00+01:00        True        True            2      False
# 2   2022-01-01T05:04:00+01:00        True        True            3      False
# 3   2022-01-01T05:08:00+01:00        True        True            4      False
# 4   2022-01-01T05:11:00+01:00        True        True            5      False
# 5   2022-01-01T05:18:00+01:00        True        True            6      False
# 6   2022-01-01T05:26:00+01:00        True        True            7      False
#
#     Disruptions
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
# 0          True
# 1         False
# 2         False
# 3         False
# 4          True
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
# 0          True
# 1         False
# 2         False
# 3         False
# 4          True
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5          True
# 6         False

# %% [markdown]
# df.to_csv('preprocessed_data/disruptions_and_main_dataset.csv', index=False)

# %%
df.to_csv('preprocessed_data/disruptions_and_main_dataset.csv', index=False)
